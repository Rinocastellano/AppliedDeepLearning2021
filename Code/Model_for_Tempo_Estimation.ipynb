# %%
#from google.colab import drive
import numpy as np
import os
from os import listdir
from os.path import isfile, join, splitext
from PIL import Image, ImageOps
import numpy as np
import random
import math
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
from keras.regularizers import l1
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras import Input
from matplotlib import pyplot

# %%
#If you didn't run the previous code that do the preprocessing -> run this part of code please
#DATASET USED FOR THE MODEL FOR TEMPO ESTIMATION, IT'S JUST PREPROCESSED
# !gdown --id 1laAPu4rWL--uQqImUVLRucxX45WioDo6
# !gdown --id 1dss_W5QL0y-C3LxuCHWO72FnXOq1nc3y

path=['Image_spec_t.zip','Ann_bpm.zip']
path_images=["Image_spec_t/"]
path_ann=["Ann_bpm/"]
from zipfile import ZipFile
for p in path:
    with ZipFile(p, 'r') as zipp:
        # printing all the contents of the zip file
        #zip.printdir()
        print('Extracting all the files now...')
        zipp.extractall()
        print('Done!')
flag=0

# %%
#If you have done the preprocessing using the previous notebook, please run this part of code
path_images=["Dataset/Tempo/GS/Image_spec","Dataset/Tempo/EXT/Image_spec"]
path_ann=["Dataset/Tempo/GS/Ann","Dataset/Tempo/EXT/Ann"]
flag=1

# %%
def split_train_test_validation(path_label,path_img):
    f_l=[]
    f_i=[]
    for i,l in zip(path_img,path_label):
        f_l.extend([os.path.join(root, name) for root, dirs, files in os.walk(l) for name in files if name.endswith((".txt"))])
        f_i.extend([os.path.join(root, name) for root, dirs, files in os.walk(i) for name in files if name.endswith((".jpeg"))]) 
    if flag==0:

        f_l=[os.path.join(f.split('/')[1],f.split('/')[2]) for f in f_l]
        f_i=[os.path.join(f.split('/')[1],f.split('/')[2]) for f in f_i]
    else:

        f_l=[f.split('/')[2]+'/'+(f.split('/')[3]).split('\\')[1] for f in f_l]
        f_i=[f.split('/')[2]+'/'+(f.split('/')[3]).split('\\')[1] for f in f_i]

    f_l= np.asarray(f_l)
    f_i= np.asarray(f_i)
    print("Sorting both images and annotations...")
    for n in range(f_l.shape[0]):
        while True:
            s=splitext(f_l[n])[0]
            if "lerch" in s:
                s=s[:len(s)-6]
            res=np.where(f_i==f"{str(s)}.jpeg")
            if(n==res[0]):
                break
            f_i[n], f_i[res[0][0]] = f_i[res[0][0]], f_i[n]
    c=list(zip(f_l,f_i))
    random.shuffle(c)
    f_l,f_i=zip(*c)
    if flag==1:
        f_l=["Dataset/Tempo/"+f.split('/')[0]+'/Ann/'+f.split('/')[1] for f in f_l]
        f_i=["Dataset/Tempo/"+f.split('/')[0]+'/Image_spec/'+f.split('/')[1] for f in f_i]
    images=[]
    ann=[]
    print("Processing the images...")
    for f in f_i:
        if flag==0:
            images.append(np.asarray(ImageOps.grayscale(Image.open(f"Image_spec_t/{f}").resize((40,256)))))
        if flag==1:
            images.append(np.asarray(ImageOps.grayscale(Image.open(f).resize((40,256)))))
    print("Processing the annotations")
    for an in f_l:
        if flag==0:
            with open(f"Ann_bpm/{an}") as f:
                bpm=int(float(f.readlines()[0]))
                ann.append(bpm)
        if flag==1:
            with open(an) as f:
                bpm=int(float(f.readlines()[0]))
                ann.append(bpm)


    min_annotation=min(ann)
    #This is a big assumption in order to avoid the wrong annotations setted as 0.
    #It is encountered 5-6 in a dataset of 10 thousands, I putted them in an average bpm
    #that usually lives between 90 and 120 bpm for pop-music
    while min_annotation==0:
        ann[ann.index(min_annotation)]=100
        min_annotation=min(ann)
    MIN_BPM=min_annotation
    max_annotation=max(ann)-min(ann)
    print(f"Minimum bpm found is {min_annotation}, the maximum is {max_annotation}")
    ann=[x-min_annotation  for x in ann]
    test_x=np.asarray(images[0:math.ceil(len(f_i)*0.2)])/255
    test_file=f_i[:math.ceil(len(f_i)*0.2)]
    test_y=np.array(ann[0:math.ceil(len(f_i)*0.2)])
    train_x=np.asarray(images[len(test_x):len(test_x)+math.ceil(len(f_i)*0.6)])/255
    train_y=np.array(ann[len(test_x):len(test_x)+math.ceil(len(f_i)*0.6)])
    val_x=np.asarray(images[len(test_x)+len(train_x):])/255
    val_y=np.array(ann[len(test_x)+len(train_x):])
    train_y = to_categorical(train_y, max_annotation+1)
    test_y = to_categorical(test_y, max_annotation+1) 
    print(max_annotation)
    print(val_y)
    val_y= to_categorical(val_y, max_annotation+1)
    print(f"Split a total of {len(f_i)} samples into three sets with {len(train_x)} training, {len(val_x)} validation and {len(test_x)} test samples.")
    return test_x,test_y,train_x,train_y,val_x,val_y,test_file,MIN_BPM


x_test,y_test,x_train,y_train,x_val,y_val,test_file,MIN_BPM=split_train_test_validation(path_ann,path_images)
# Out:
# ['Dataset/Tempo/GS/Ann\\1030011.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1068430.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1084996.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1092771.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1114156.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1118326.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1120171.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1171800.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1174239.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1177875.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1183908.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1198571.LOFI.txt', 'Dataset/Tempo/GS/Ann\\122772.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1234668.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1234669.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1234745.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1234750.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1240669.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1240672.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1317507.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1327052.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1329955.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1380256.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1418652.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1424458.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1461087.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1469706.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1479462.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1514866.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1548088.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1556416.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1560139.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1560729.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1562235.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1569136.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1623443.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1626348.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1676961.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1698047.LOFI.txt', 'Dataset/Tempo/GS/Ann\\172384.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1728723.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1735621.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1743969.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1747518.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1753073.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1765409.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1791554.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1816200.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1817444.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1825982.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1839656.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1842615.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1851619.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1855660.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1874244.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1885798.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1889739.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1889844.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1896782.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1905591.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1905592.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1918704.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1921248.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1929611.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1943706.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1950701.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1955621.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1960598.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1968659.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1973680.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1974485.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1982430.LOFI.txt', 'Dataset/Tempo/GS/Ann\\1982431.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2013128.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2022116.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2039114.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2048806.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2061919.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2071203.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2083393.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2083969.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2088277.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2088281.LOFI.txt', 'Dataset/Tempo/GS/Ann\\210560.LOFI.txt', 'Dataset/Tempo/GS/Ann\\220883.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2422602.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2432724.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2442269.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2673896.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2676246.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2676506.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2677224.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2702022.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2703359.LOFI.txt', 'Dataset/Tempo/GS/Ann\\2704868.LOFI.txt', 'Dataset/Temp ...
# ['Dataset/Tempo/GS/Image_spec\\100601.jpeg', 'Dataset/Tempo/GS/Image_spec\\100602.jpeg', 'Dataset/Tempo/GS/Image_spec\\100603.jpeg', 'Dataset/Tempo/GS/Image_spec\\100604.jpeg', 'Dataset/Tempo/GS/Image_spec\\100605.jpeg', 'Dataset/Tempo/GS/Image_spec\\100606.jpeg', 'Dataset/Tempo/GS/Image_spec\\100607.jpeg', 'Dataset/Tempo/GS/Image_spec\\100608.jpeg',
spec\\101012.jpeg', 'Dataset/Tempo/GS/Image_spec\\101013.jpeg', 'Dataset/Tempo/GS/Image_spec\\101014.jpeg', 'Dataset/Tempo/GS/Image_spec\\101015.jpeg', 'Dataset/Tempo/GS/Image_spec\\101016.jpeg', 'Dataset/Tempo/GS/Image_spec\\101017.jpeg', 'Dataset/Tempo/GS/Image_spec\\101018.jpeg', 'Dataset/Tempo/GS/Image_spec\\101101.jpeg', 'Dataset/Tempo/GS/Image_spec\\101102.jpeg', 'Dataset/Tempo/GS/Image_spec\\101103.jpeg', 'Dataset/Tempo/GS/Image_spec\\101104.jpeg', 'Dataset/Tempo/GS/Image_spec\\101105.jpeg', 'Dataset/Tempo/GS/Image_spec\\101106.jpeg', 'Dataset/Tempo/GS/Image_spec\\101107.jpeg', 'Dataset/Tempo/GS/Image_spec\\101108.jpeg', 'Dataset/Tempo/GS/Image_spec\\101109.jpeg', 'Dataset/Tempo/GS/Image_spec\\101110.jpeg', 'Dataset/Tempo/GS/Image_spec\\101111.jpeg', 'Dataset/Tempo/GS/Image_spec\\101112.jpeg', 'Dataset/Tempo/GS/Image_spec\\101113.jpeg', 'Dataset/Tempo/GS/Image_spec\\101114.jpeg', 'Dataset/Tempo/GS/Image_spec\\101115.jpeg', 'Dataset/Tempo/GS/Image_spec\\101116.jpeg', 'Dataset/Tempo/GS/Image_spec\\101201.jpeg', 'Dataset/Tempo/GS/Image_spec\\101202.jpeg', 'Dataset/Tempo/GS/Image_spec\\101203.jpeg', 'Dataset/Tempo/GS/Image_spec\\101204.jpeg', 'Dataset/Tempo/GS/Image_spec\\101205.jpeg', 'Dataset/Tempo/GS/Image_spec\\101206.jpeg', 'Dataset/Tempo/GS/Image_spec\\101207.jpeg', 'Dataset/Tempo/GS/Image_spec\\101208.jp ...
# ['Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\ ...
# ['Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\GS', 'Tempo\\ ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-8cc146864c9a> in <module>
#      64
#      65
# ---> 66 x_test,y_test,x_train,y_train,x_val,y_val,test_file,MIN_BPM=split_train_test_validation(path_ann,path_images)
#
# <ipython-input-10-8cc146864c9a> in split_train_test_validation(path_label, path_img)
#       7         print(f_l)
#       8         print(f_i)
# ----> 9         f_l=[os.path.join(f.split('/')[1],f.split('/')[2]) for f in f_l]
#      10         f_i=[os.path.join(f.split('/')[1],f.split('/')[2]) for f in f_i]
#      11
#
# <ipython-input-10-8cc146864c9a> in <listcomp>(.0)
#       7         print(f_l)
#       8         print(f_i)
# ----> 9         f_l=[os.path.join(f.split('/')[1],f.split('/')[2]) for f in f_l]
#      10         f_i=[os.path.join(f.split('/')[1],f.split('/')[2]) for f in f_i]
#      11
#
# IndexError: list index out of range

# %%
model = tf.keras.Sequential([
    layers.Conv2D(16, (5, 5), activation='relu', input_shape=(256, 40,1)),
    layers.MaxPooling2D((2, 2)),
    layers.BatchNormalization(),
    layers.Conv2D(32, (5, 5), activation='relu'), 
    layers.MaxPooling2D((2, 2)),
    layers.BatchNormalization(),
    layers.Conv2D(32, (5, 5), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.BatchNormalization(),
    tf.keras.layers.Reshape(target_shape=(-1,32), name='reshape'),           
    layers.Bidirectional(layers.LSTM(32, return_sequences=True,activation='tanh')),
    layers.Bidirectional(layers.LSTM(32, return_sequences=True,activation='tanh')),
    layers.BatchNormalization(),
    layers.Dropout(0.4),
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(153,activation='softmax')
    
])
model.build((256,40))
model.summary()
model.compile(optimizer=tf.keras.optimizers.Adagrad(learning_rate=0.055),loss='categorical_crossentropy',metrics=['acc'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
history = model.fit(x_train, y_train, epochs=75, batch_size=99,validation_data=(x_val, y_val))

# %%
pyplot.plot(history.history['acc'], label='train')
pyplot.plot(history.history['val_acc'], label='test')

# %%
#As explained in the readme, the accuracy for tempo estimation is stated as follows:
#if the Tempo is doubled or halfed, error of 50% (Ex. Label: 80 BPM, Prediction: 160 BPM)
#if the Tempo is between a tollerance interval, error of 0% (Ex. Label: 80 BPM, Prediction: 82 BPM (Tolerance of 8%))
def get_accuracy(model, true_x, true_y): 
    res = model.predict(true_x)
    res = np.argmax(res, axis=-1)
    acc = 0
    tol=0.08
    for i in range(len(true_y)):
        r=res[i]
        t=true_y[i]
        if r>t-(t*tol) and r<t+(t*tol):
          acc+=1
        elif (r>2*t-(t*tol) and r<2*t+(t*tol)) or (r>t//2-(t*tol) and r<t//2+(t*tol)):
          acc+=0.5
        else:
            pass
    tot = len(true_y)
    print('acc0 : {}'.format((acc0/tot)))
    print('acc1 : {}'.format((acc1/tot)))
    print('acc2 : {}'.format((acc2/tot)))

#This function is implemented in order to have the training dataset distinguished for the original dataset, indeed
#the output are the ExtendedBallroom and Giantsteps dataset
def get_training_dataset(label,img,test_file):
  f_l=[]
  f_i=[]
  for i,l in zip(img,label):
    f_l.extend([os.path.join(root, name) for root, dirs, files in os.walk(l) for name in files if name.endswith((".txt"))])
    f_i.extend([os.path.join(root, name) for root, dirs, files in os.walk(i) for name in files if name.endswith((".jpeg"))])
  f_l= np.asarray(f_l)
  f_i= np.asarray(f_i)
  for n in range(f_l.shape[0]):
    while True:
      s=splitext(f_l[n])[0]
      if "lerch" in s:
        s=s[:len(s)-6]
      res=np.flatnonzero(np.core.defchararray.find(f_i,f"{str(s).split('/')[-1]}")!=-1)
      if(n==res[0]):
        break
      f_i[n], f_i[res[0]] = f_i[res[0]], f_i[n]
  c=list(zip(f_l,f_i))
  giant_i=[]
  ext_i=[]
  ext_l=[]
  giant_l=[]
  lofi="LOFI"
  
  for f in f_i:
    if f in test_file: 
      if lofi in f:
        idx=np.where(f_i == f)
        giant_i.append(f)
        giant_l.append(f_l[idx])
      else:
        idx=np.where(f_i == f)
        ext_i.append(f)
        ext_l.append(f_l[idx])
  e_i=[]
  e_l=[]
  gi_i=[]
  gi_l=[]
  for g1 in ext_i:
    e_i.append(np.asarray(ImageOps.grayscale(Image.open(f"Image_spec_t/{g1}").resize((40,512))))/255)
  for g2 in giant_i:  
    gi_i.append(np.asarray(ImageOps.grayscale(Image.open(f"Image_spec_t/{g2}").resize((40,512))))/255)
  for g1 in ext_l:
    with open(f"Ann_bpm/{g1[0]}") as f:
      e_l.append(int(float(f.readlines()[0])))
  for g2 in giant_l:
    with open(f"Ann_bpm/{g2[0]}") as f:
      gi_l.append(int(float(f.readlines()[0])))
  e_i=np.asarray(e_i)
  e_l=np.asarray(e_l)
  gi_i=np.asarray(gi_i)
  gi_l=np.asarray(gi_l)
  return e_i,e_l,gi_i,gi_l
  
e_i,e_l,giant_i,giant_l=get_dataset(path_ann,path_images,test_file)

# %%
get_accuracy(model,e_i,e_l)
get_accuracy(model,giant_i,giant_l)
